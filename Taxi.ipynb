# %%
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !pip install colabgymrender==1.0.2
# Out:
# ...
#   Created wheel for colabgymrender: filename=colabgymrender-1.0.2-py3-none-any.whl size=2444 sha256=fa1e71ccac1993426672ed417dd7ee76f52cfb15dc6fcc82c2dcb66a96aa9006
#   Stored in directory: /root/.cache/pip/wheels/1f/56/73/3697080da5fc7b120516aef37d1d1eb2380515ba9e272b8ccd
# Successfully built colabgymrender
# ...

# %%
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unrar e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/
# Out:
# --2021-09-22 05:21:35--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11128004 (11M) [application/x-rar-compressed]
# Saving to: ‘Roms.rar’
#
# Roms.rar            100%[===================>]  10.61M   731KB/s    in 15s
#
# 2021-09-22 05:21:51 (706 KB/s) - ‘Roms.rar’ saved [11128004/11128004]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/Roms.rar
#
#   OK
#   OK
# All OK
# copying adventure.bin from HC ROMS/BY ALPHABET (PAL)/A-G/Adventure (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/adventure.bin
# copying air_raid.bin from HC ROMS/BY ALPHABET (PAL)/A-G/Air Raid (PAL).bin to /usr/local/lib/python3.7/dist-packages/atari_py/atari_roms/air_raid.bin
# ...

# %%
import gym
from colabgymrender.recorder import Recorder
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
env = gym.make('Taxi-v3')
done = False
obs = env.reset()

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
q_table = np.zeros([env.observation_space.n,env.action_space.n])
gamma = 0.6
alpha = 0.1
epsilon = 1
frames=0
wins=0
for _ in range(1000000):
  obs = env.reset()
  done = False
  while not done:
    frames+=1
    if frames<1000000 or epsilon > np.random.rand(1)[0]:
      action = env.action_space.sample()
    else:
      action = np.argmax(q_table[obs])

    obs_,reward,done,info = env.step(action)

    epsilon-= 0.99/100000
    epsilon = max(epsilon,0.1)

    q_table[obs,action] = (1-alpha)*q_table[obs,action] + alpha*(reward + gamma*np.max(q_table[obs_]))

    if reward==20:
      wins+=1

    obs = obs_

# %%
q_table = np.load('/content/gdrive/My Drive/Reinforcement-Learning-project/taxi_qtable.npy') #importing pre-trained q-table

# %%
done = False
obs = env.reset()
actions = []
solved=0
i=0
for _ in range(40):
  done=False
  obs = env.reset()
  reward = 0
  while not done:
    a = np.argmax(q_table[obs])
    actions.append(a)
    obs,r,done,info = env.step(a)
    if r==20:
      solved+=1

print(solved)
# Out:
# 40
